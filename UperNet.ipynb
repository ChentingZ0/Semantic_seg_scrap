# %%
# !pip install -q git+https://github.com/huggingface/transformers.git

# %%
from transformers import UperNetForSemanticSegmentation
import torch
model = UperNetForSemanticSegmentation.from_pretrained("openmmlab/upernet-swin-tiny")

# %%
model_dict = model.state_dict()
print(list(model_dict.keys())[:10])
print(list(model_dict.keys())[-10:])
# Out:
# ['backbone.embeddings.patch_embeddings.projection.weight', 'backbone.embeddings.patch_embeddings.projection.bias', 'backbone.embeddings.norm.weight', 'backbone.embeddings.norm.bias', 'backbone.encoder.layers.0.blocks.0.layernorm_before.weight', 'backbone.encoder.layers.0.blocks.0.layernorm_before.bias', 'backbone.encoder.layers.0.blocks.0.attention.self.relative_position_bias_table', 'backbone.encoder.layers.0.blocks.0.attention.self.relative_position_index', 'backbone.encoder.layers.0.blocks.0.attention.self.query.weight', 'backbone.encoder.layers.0.blocks.0.attention.self.query.bias']
# ['decode_head.fpn_bottleneck.batch_norm.running_var', 'decode_head.fpn_bottleneck.batch_norm.num_batches_tracked', 'auxiliary_head.convs.0.conv.weight', 'auxiliary_head.convs.0.batch_norm.weight', 'auxiliary_head.convs.0.batch_norm.bias', 'auxiliary_head.convs.0.batch_norm.running_mean', 'auxiliary_head.convs.0.batch_norm.running_var', 'auxiliary_head.convs.0.batch_norm.num_batches_tracked', 'auxiliary_head.classifier.weight', 'auxiliary_head.classifier.bias']

# %%
model.eval()  # Set the model to evaluation mode

# Move model to a suitable device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Create a dummy input tensor with the expected shape (batch_size, channels, height, width)
dummy_input = torch.randn(1, 3, 512, 512).to(device)  # Adjust dimensions if necessary

# Print a summary by passing the dummy input
with torch.no_grad():
    output = model(dummy_input)
    print(model)  # This will print the architecture
# Out:
# UperNetForSemanticSegmentation(
#   (backbone): SwinBackbone(
#     (embeddings): SwinEmbeddings(
#       (patch_embeddings): SwinPatchEmbeddings(
#         (projection): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#       )
#       (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): SwinEncoder(
#       (layers): ModuleList(
#         (0): SwinStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (layernorm_before): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=96, out_features=96, bias=True)
#                   (key): Linear(in_features=96, out_features=96, bias=True)
#                   (value): Linear(in_features=96, out_features=96, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=96, out_features=96, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): Identity()
#               (layernorm_after): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=96, out_features=384, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=384, out_features=96, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (layernorm_before): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=96, out_features=96, bias=True)
#                   (key): Linear(in_features=96, out_features=96, bias=True)
#                   (value): Linear(in_features=96, out_features=96, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=96, out_features=96, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.00909090880304575)
#               (layernorm_after): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=96, out_features=384, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=384, out_features=96, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#           (downsample): SwinPatchMerging(
#             (reduction): Linear(in_features=384, out_features=192, bias=False)
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): SwinStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=192, out_features=192, bias=True)
#                   (key): Linear(in_features=192, out_features=192, bias=True)
#                   (value): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.0181818176060915)
#               (layernorm_after): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=192, out_features=768, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=192, out_features=192, bias=True)
#                   (key): Linear(in_features=192, out_features=192, bias=True)
#                   (value): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.027272727340459824)
#               (layernorm_after): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=192, out_features=768, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#           (downsample): SwinPatchMerging(
#             (reduction): Linear(in_features=768, out_features=384, bias=False)
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): SwinStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.036363635212183)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.045454543083906174)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (2): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.054545458406209946)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (3): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.06363636255264282)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (4): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.0727272778749466)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (5): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.08181818574666977)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#           (downsample): SwinPatchMerging(
#             (reduction): Linear(in_features=1536, out_features=768, bias=False)
#             (norm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): SwinStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (layernorm_before): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.09090909361839294)
#               (layernorm_after): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (layernorm_before): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.10000000149011612)
#               (layernorm_after): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#         )
#       )
#     )
#     (hidden_states_norms): ModuleDict(
#       (stage1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#       (stage2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (stage3): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (stage4): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decode_head): UperNetHead(
#     (classifier): Conv2d(512, 150, kernel_size=(1, 1), stride=(1, 1))
#     (psp_modules): UperNetPyramidPoolingModule(
#       (0): UperNetPyramidPoolingBlock(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): UperNetConvModule(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#       )
#       (1): UperNetPyramidPoolingBlock(
#         (0): AdaptiveAvgPool2d(output_size=2)
#         (1): UperNetConvModule(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#       )
#       (2): UperNetPyramidPoolingBlock(
#         (0): AdaptiveAvgPool2d(output_size=3)
#         (1): UperNetConvModule(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#       )
#       (3): UperNetPyramidPoolingBlock(
#         (0): AdaptiveAvgPool2d(output_size=6)
#         (1): UperNetConvModule(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#       )
#     )
#     (bottleneck): UperNetConvModule(
#       (conv): Conv2d(2816, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#     (lateral_convs): ModuleList(
#       (0): UperNetConvModule(
#         (conv): Conv2d(96, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#       (1): UperNetConvModule(
#         (conv): Conv2d(192, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#       (2): UperNetConvModule(
#         (conv): Conv2d(384, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#     )
#     (fpn_convs): ModuleList(
#       (0-2): 3 x UperNetConvModule(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#     )
#     (fpn_bottleneck): UperNetConvModule(
#       (conv): Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#   )
#   (auxiliary_head): UperNetFCNHead(
#     (convs): Sequential(
#       (0): UperNetConvModule(
#         (conv): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#     )
#     (classifier): Conv2d(256, 150, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
# Print state_dict keys with non-empty and non-zero parameters
for key, param in model.state_dict().items():
    if param.numel() > 0 and torch.sum(param).item() != 0:  # Check for non-empty and non-zero tensors
        print(key)
# Out:
# backbone.embeddings.patch_embeddings.projection.weight
# backbone.embeddings.patch_embeddings.projection.bias
# backbone.embeddings.norm.weight
# backbone.embeddings.norm.bias
# backbone.encoder.layers.0.blocks.0.layernorm_before.weight
# backbone.encoder.layers.0.blocks.0.layernorm_before.bias
# backbone.encoder.layers.0.blocks.0.attention.self.relative_position_bias_table
# backbone.encoder.layers.0.blocks.0.attention.self.relative_position_index
# backbone.encoder.layers.0.blocks.0.attention.self.query.weight
# backbone.encoder.layers.0.blocks.0.attention.self.query.bias
# backbone.encoder.layers.0.blocks.0.attention.self.key.weight
# backbone.encoder.layers.0.blocks.0.attention.self.key.bias
# backbone.encoder.layers.0.blocks.0.attention.self.value.weight
# backbone.encoder.layers.0.blocks.0.attention.self.value.bias
# backbone.encoder.layers.0.blocks.0.attention.output.dense.weight
# backbone.encoder.layers.0.blocks.0.attention.output.dense.bias
# backbone.encoder.layers.0.blocks.0.layernorm_after.weight
# backbone.encoder.layers.0.blocks.0.layernorm_after.bias
# backbone.encoder.layers.0.blocks.0.intermediate.dense.weight
# backbone.encoder.layers.0.blocks.0.intermediate.dense.bias
# backbone.encoder.layers.0.blocks.0.output.dense.weight
# backbone.encoder.layers.0.blocks.0.output.dense.bias
# backbone.encoder.layers.0.blocks.1.layernorm_before.weight
# backbone.encoder.layers.0.blocks.1.layernorm_before.bias
# backbone.encoder.layers.0.blocks.1.attention.self.relative_position_bias_table
# backbone.encoder.layers.0.blocks.1.attention.self.relative_position_index
# backbone.encoder.layers.0.blocks.1.attention.self.query.weight
# backbone.encoder.layers.0.blocks.1.attention.self.query.bias
# backbone.encoder.layers.0.blocks.1.attention.self.key.weight
# backbone.encoder.layers.0.blocks.1.attention.self.key.bias
# backbone.encoder.layers.0.blocks.1.attention.self.value.weight
# backbone.encoder.layers.0.blocks.1.attention.self.value.bias
# backbone.encoder.layers.0.blocks.1.attention.output.dense.weight
# backbone.encoder.layers.0.blocks.1.attention.output.dense.bias
# backbone.encoder.layers.0.blocks.1.layernorm_after.weight
# backbone.encoder.layers.0.blocks.1.layernorm_after.bias
# backbone.encoder.layers.0.blocks.1.intermediate.dense.weight
# backbone.encoder.layers.0.blocks.1.intermediate.dense.bias
# backbone.encoder.layers.0.blocks.1.output.dense.weight
# backbone.encoder.layers.0.blocks.1.output.dense.bias
# backbone.encoder.layers.0.downsample.reduction.weight
# backbone.encoder.layers.0.downsample.norm.weight
# backbone.encoder.layers.0.downsample.norm.bias
# backbone.encoder.layers.1.blocks.0.layernorm_before.weight
# backbone.encoder.layers.1.blocks.0.layernorm_before.bias
# backbone.encoder.layers.1.blocks.0.attention.self.relative_position_bias_table
# backbone.encoder.layers.1.blocks.0.attention.self.relative_position_index
# backbone.encoder.layers.1.blocks.0.attention.self.query.weight
# backbone.encoder.layers.1.blocks.0.attention.self.query.bias
# backbone.encoder.layers.1.blocks.0.attention.self.key.weight
# backbone.encoder.layers.1.blocks.0.attention.self.key.bias
# backbone.encoder.layers.1.blocks.0.attention.self.value.weight
# backbone.encoder.layers.1.blocks.0.attention.self.value.bias
# backbone.encoder.layers.1.blocks.0.attention.output.dense.weight
# backbone.encoder.layers.1.blocks.0.attention.output.dense.bias
# backbone.encoder.layers.1.blocks.0.layernorm_after.weight
# backbone.encoder.layers.1.blocks.0.layernorm_after.bias
# backbone.encoder.layers.1.blocks.0.intermediate.dense.weight
# backbone.encoder.layers.1.blocks.0.intermediate.dense.bias
# backbone.encoder.layers.1.blocks.0.output.dense.weight
# backbone.encoder.layers.1.blocks.0.output.dense.bias
# backbone.encoder.layers.1.blocks.1.layernorm_before.weight
# backbone.encoder.layers.1.blocks.1.layernorm_before.bias
# backbone.encoder.layers.1.blocks.1.attention.self.relative_position_bias_table
# backbone.encoder.layers.1.blocks.1.attention.self.relative_position_index
# backbone.encoder.layers.1.blocks.1.attention.self.query.weight
# backbone.encoder.layers.1.blocks.1.attention.self.query.bias
# backbone.encoder.layers.1.blocks.1.attention.self.key.weight
# backbone.encoder.layers.1.blocks.1.attention.self.key.bias
# backbone.encoder.layers.1.blocks.1.attention.self.value.weight
# backbone.encoder.layers.1.blocks.1.attention.self.value.bias
# backbone.encoder.layers.1.blocks.1.attention.output.dense.weight
# backbone.encoder.layers.1.blocks.1.attention.output.dense.bias
# backbone.encoder.layers.1.blocks.1.layernorm_after.weight
# backbone.encoder.layers.1.blocks.1.layernorm_after.bias
# backbone.encoder.layers.1.blocks.1.intermediate.dense.weight
# backbone.encoder.layers.1.blocks.1.intermediate.dense.bias
# backbone.encoder.layers.1.blocks.1.output.dense.weight
# backbone.encoder.layers.1.blocks.1.output.dense.bias
# backbone.encoder.layers.1.downsample.reduction.weight
# backbone.encoder.layers.1.downsample.norm.weight
# backbone.encoder.layers.1.downsample.norm.bias
# backbone.encoder.layers.2.blocks.0.layernorm_before.weight
# backbone.encoder.layers.2.blocks.0.layernorm_before.bias
# backbone.encoder.layers.2.blocks.0.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.0.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.0.attention.self.query.weight
# backbone.encoder.layers.2.blocks.0.attention.self.query.bias
# backbone.encoder.layers.2.blocks.0.attention.self.key.weight
# backbone.encoder.layers.2.blocks.0.attention.self.key.bias
# backbone.encoder.layers.2.blocks.0.attention.self.value.weight
# backbone.encoder.layers.2.blocks.0.attention.self.value.bias
# backbone.encoder.layers.2.blocks.0.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.0.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.0.layernorm_after.weight
# backbone.encoder.layers.2.blocks.0.layernorm_after.bias
# backbone.encoder.layers.2.blocks.0.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.0.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.0.output.dense.weight
# backbone.encoder.layers.2.blocks.0.output.dense.bias
# backbone.encoder.layers.2.blocks.1.layernorm_before.weight
# backbone.encoder.layers.2.blocks.1.layernorm_before.bias
# backbone.encoder.layers.2.blocks.1.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.1.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.1.attention.self.query.weight
# backbone.encoder.layers.2.blocks.1.attention.self.query.bias
# backbone.encoder.layers.2.blocks.1.attention.self.key.weight
# backbone.encoder.layers.2.blocks.1.attention.self.key.bias
# backbone.encoder.layers.2.blocks.1.attention.self.value.weight
# backbone.encoder.layers.2.blocks.1.attention.self.value.bias
# backbone.encoder.layers.2.blocks.1.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.1.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.1.layernorm_after.weight
# backbone.encoder.layers.2.blocks.1.layernorm_after.bias
# backbone.encoder.layers.2.blocks.1.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.1.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.1.output.dense.weight
# backbone.encoder.layers.2.blocks.1.output.dense.bias
# backbone.encoder.layers.2.blocks.2.layernorm_before.weight
# backbone.encoder.layers.2.blocks.2.layernorm_before.bias
# backbone.encoder.layers.2.blocks.2.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.2.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.2.attention.self.query.weight
# backbone.encoder.layers.2.blocks.2.attention.self.query.bias
# backbone.encoder.layers.2.blocks.2.attention.self.key.weight
# backbone.encoder.layers.2.blocks.2.attention.self.key.bias
# backbone.encoder.layers.2.blocks.2.attention.self.value.weight
# backbone.encoder.layers.2.blocks.2.attention.self.value.bias
# backbone.encoder.layers.2.blocks.2.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.2.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.2.layernorm_after.weight
# backbone.encoder.layers.2.blocks.2.layernorm_after.bias
# backbone.encoder.layers.2.blocks.2.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.2.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.2.output.dense.weight
# backbone.encoder.layers.2.blocks.2.output.dense.bias
# backbone.encoder.layers.2.blocks.3.layernorm_before.weight
# backbone.encoder.layers.2.blocks.3.layernorm_before.bias
# backbone.encoder.layers.2.blocks.3.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.3.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.3.attention.self.query.weight
# backbone.encoder.layers.2.blocks.3.attention.self.query.bias
# backbone.encoder.layers.2.blocks.3.attention.self.key.weight
# backbone.encoder.layers.2.blocks.3.attention.self.key.bias
# backbone.encoder.layers.2.blocks.3.attention.self.value.weight
# backbone.encoder.layers.2.blocks.3.attention.self.value.bias
# backbone.encoder.layers.2.blocks.3.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.3.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.3.layernorm_after.weight
# backbone.encoder.layers.2.blocks.3.layernorm_after.bias
# backbone.encoder.layers.2.blocks.3.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.3.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.3.output.dense.weight
# backbone.encoder.layers.2.blocks.3.output.dense.bias
# backbone.encoder.layers.2.blocks.4.layernorm_before.weight
# backbone.encoder.layers.2.blocks.4.layernorm_before.bias
# backbone.encoder.layers.2.blocks.4.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.4.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.4.attention.self.query.weight
# backbone.encoder.layers.2.blocks.4.attention.self.query.bias
# backbone.encoder.layers.2.blocks.4.attention.self.key.weight
# backbone.encoder.layers.2.blocks.4.attention.self.key.bias
# backbone.encoder.layers.2.blocks.4.attention.self.value.weight
# backbone.encoder.layers.2.blocks.4.attention.self.value.bias
# backbone.encoder.layers.2.blocks.4.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.4.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.4.layernorm_after.weight
# backbone.encoder.layers.2.blocks.4.layernorm_after.bias
# backbone.encoder.layers.2.blocks.4.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.4.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.4.output.dense.weight
# backbone.encoder.layers.2.blocks.4.output.dense.bias
# backbone.encoder.layers.2.blocks.5.layernorm_before.weight
# backbone.encoder.layers.2.blocks.5.layernorm_before.bias
# backbone.encoder.layers.2.blocks.5.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.5.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.5.attention.self.query.weight
# backbone.encoder.layers.2.blocks.5.attention.self.query.bias
# backbone.encoder.layers.2.blocks.5.attention.self.key.weight
# backbone.encoder.layers.2.blocks.5.attention.self.key.bias
# backbone.encoder.layers.2.blocks.5.attention.self.value.weight
# backbone.encoder.layers.2.blocks.5.attention.self.value.bias
# backbone.encoder.layers.2.blocks.5.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.5.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.5.layernorm_after.weight
# backbone.encoder.layers.2.blocks.5.layernorm_after.bias
# backbone.encoder.layers.2.blocks.5.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.5.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.5.output.dense.weight
# backbone.encoder.layers.2.blocks.5.output.dense.bias
# backbone.encoder.layers.2.downsample.reduction.weight
# backbone.encoder.layers.2.downsample.norm.weight
# backbone.encoder.layers.2.downsample.norm.bias
# backbone.encoder.layers.3.blocks.0.layernorm_before.weight
# backbone.encoder.layers.3.blocks.0.layernorm_before.bias
# backbone.encoder.layers.3.blocks.0.attention.self.relative_position_bias_table
# backbone.encoder.layers.3.blocks.0.attention.self.relative_position_index
# backbone.encoder.layers.3.blocks.0.attention.self.query.weight
# backbone.encoder.layers.3.blocks.0.attention.self.query.bias
# backbone.encoder.layers.3.blocks.0.attention.self.key.weight
# backbone.encoder.layers.3.blocks.0.attention.self.key.bias
# backbone.encoder.layers.3.blocks.0.attention.self.value.weight
# backbone.encoder.layers.3.blocks.0.attention.self.value.bias
# backbone.encoder.layers.3.blocks.0.attention.output.dense.weight
# backbone.encoder.layers.3.blocks.0.attention.output.dense.bias
# backbone.encoder.layers.3.blocks.0.layernorm_after.weight
# backbone.encoder.layers.3.blocks.0.layernorm_after.bias
# backbone.encoder.layers.3.blocks.0.intermediate.dense.weight
# backbone.encoder.layers.3.blocks.0.intermediate.dense.bias
# backbone.encoder.layers.3.blocks.0.output.dense.weight
# backbone.encoder.layers.3.blocks.0.output.dense.bias
# backbone.encoder.layers.3.blocks.1.layernorm_before.weight
# backbone.encoder.layers.3.blocks.1.layernorm_before.bias
# backbone.encoder.layers.3.blocks.1.attention.self.relative_position_bias_table
# backbone.encoder.layers.3.blocks.1.attention.self.relative_position_index
# backbone.encoder.layers.3.blocks.1.attention.self.query.weight
# backbone.encoder.layers.3.blocks.1.attention.self.query.bias
# backbone.encoder.layers.3.blocks.1.attention.self.key.weight
# backbone.encoder.layers.3.blocks.1.attention.self.key.bias
# backbone.encoder.layers.3.blocks.1.attention.self.value.weight
# backbone.encoder.layers.3.blocks.1.attention.self.value.bias
# backbone.encoder.layers.3.blocks.1.attention.output.dense.weight
# backbone.encoder.layers.3.blocks.1.attention.output.dense.bias
# backbone.encoder.layers.3.blocks.1.layernorm_after.weight
# backbone.encoder.layers.3.blocks.1.layernorm_after.bias
# backbone.encoder.layers.3.blocks.1.intermediate.dense.weight
# backbone.encoder.layers.3.blocks.1.intermediate.dense.bias
# backbone.encoder.layers.3.blocks.1.output.dense.weight
# backbone.encoder.layers.3.blocks.1.output.dense.bias
# backbone.hidden_states_norms.stage1.weight
# backbone.hidden_states_norms.stage1.bias
# backbone.hidden_states_norms.stage2.weight
# backbone.hidden_states_norms.stage2.bias
# backbone.hidden_states_norms.stage3.weight
# backbone.hidden_states_norms.stage3.bias
# backbone.hidden_states_norms.stage4.weight
# backbone.hidden_states_norms.stage4.bias
# decode_head.classifier.weight
# decode_head.classifier.bias
# decode_head.psp_modules.0.1.conv.weight
# decode_head.psp_modules.0.1.batch_norm.weight
# decode_head.psp_modules.0.1.batch_norm.bias
# decode_head.psp_modules.0.1.batch_norm.running_mean
# decode_head.psp_modules.0.1.batch_norm.running_var
# decode_head.psp_modules.0.1.batch_norm.num_batches_tracked
# decode_head.psp_modules.1.1.conv.weight
# decode_head.psp_modules.1.1.batch_norm.weight
# decode_head.psp_modules.1.1.batch_norm.bias
# decode_head.psp_modules.1.1.batch_norm.running_mean
# decode_head.psp_modules.1.1.batch_norm.running_var
# decode_head.psp_modules.1.1.batch_norm.num_batches_tracked
# decode_head.psp_modules.2.1.conv.weight
# decode_head.psp_modules.2.1.batch_norm.weight
# decode_head.psp_modules.2.1.batch_norm.bias
# decode_head.psp_modules.2.1.batch_norm.running_mean
# decode_head.psp_modules.2.1.batch_norm.running_var
# decode_head.psp_modules.2.1.batch_norm.num_batches_tracked
# decode_head.psp_modules.3.1.conv.weight
# decode_head.psp_modules.3.1.batch_norm.weight
# decode_head.psp_modules.3.1.batch_norm.bias
# decode_head.psp_modules.3.1.batch_norm.running_mean
# decode_head.psp_modules.3.1.batch_norm.running_var
# decode_head.psp_modules.3.1.batch_norm.num_batches_tracked
# decode_head.bottleneck.conv.weight
# decode_head.bottleneck.batch_norm.weight
# decode_head.bottleneck.batch_norm.bias
# decode_head.bottleneck.batch_norm.running_mean
# decode_head.bottleneck.batch_norm.running_var
# decode_head.bottleneck.batch_norm.num_batches_tracked
# decode_head.lateral_convs.0.conv.weight
# decode_head.lateral_convs.0.batch_norm.weight
# decode_head.lateral_convs.0.batch_norm.bias
# decode_head.lateral_convs.0.batch_norm.running_mean
# decode_head.lateral_convs.0.batch_norm.running_var
# decode_head.lateral_convs.0.batch_norm.num_batches_tracked
# decode_head.lateral_convs.1.conv.weight
# decode_head.lateral_convs.1.batch_norm.weight
# decode_head.lateral_convs.1.batch_norm.bias
# decode_head.lateral_convs.1.batch_norm.running_mean
# decode_head.lateral_convs.1.batch_norm.running_var
# decode_head.lateral_convs.1.batch_norm.num_batches_tracked
# decode_head.lateral_convs.2.conv.weight
# decode_head.lateral_convs.2.batch_norm.weight
# decode_head.lateral_convs.2.batch_norm.bias
# decode_head.lateral_convs.2.batch_norm.running_mean
# decode_head.lateral_convs.2.batch_norm.running_var
# decode_head.lateral_convs.2.batch_norm.num_batches_tracked
# decode_head.fpn_convs.0.conv.weight
# decode_head.fpn_convs.0.batch_norm.weight
# decode_head.fpn_convs.0.batch_norm.bias
# decode_head.fpn_convs.0.batch_norm.running_mean
# decode_head.fpn_convs.0.batch_norm.running_var
# decode_head.fpn_convs.0.batch_norm.num_batches_tracked
# decode_head.fpn_convs.1.conv.weight
# decode_head.fpn_convs.1.batch_norm.weight
# decode_head.fpn_convs.1.batch_norm.bias
# decode_head.fpn_convs.1.batch_norm.running_mean
# decode_head.fpn_convs.1.batch_norm.running_var
# decode_head.fpn_convs.1.batch_norm.num_batches_tracked
# decode_head.fpn_convs.2.conv.weight
# decode_head.fpn_convs.2.batch_norm.weight
# decode_head.fpn_convs.2.batch_norm.bias
# decode_head.fpn_convs.2.batch_norm.running_mean
# decode_head.fpn_convs.2.batch_norm.running_var
# decode_head.fpn_convs.2.batch_norm.num_batches_tracked
# decode_head.fpn_bottleneck.conv.weight
# decode_head.fpn_bottleneck.batch_norm.weight
# decode_head.fpn_bottleneck.batch_norm.bias
# decode_head.fpn_bottleneck.batch_norm.running_mean
# decode_head.fpn_bottleneck.batch_norm.running_var
# decode_head.fpn_bottleneck.batch_norm.num_batches_tracked
# auxiliary_head.convs.0.conv.weight
# auxiliary_head.convs.0.batch_norm.weight
# auxiliary_head.convs.0.batch_norm.bias
# auxiliary_head.convs.0.batch_norm.running_mean
# auxiliary_head.convs.0.batch_norm.running_var
# auxiliary_head.convs.0.batch_norm.num_batches_tracked
# auxiliary_head.classifier.weight
# auxiliary_head.classifier.bias

# %%
import torch
from transformers import UperNetForSemanticSegmentation

# Load the pretrained UperNet model
model = UperNetForSemanticSegmentation.from_pretrained("openmmlab/upernet-swin-tiny")

# Update the main classifier layer in `decode_head`
model.decode_head.classifier = torch.nn.Conv2d(
    in_channels=model.decode_head.classifier.in_channels,  # Keep the same input channels
    out_channels=4,  # Change the output channels to 4 classes
    kernel_size=model.decode_head.classifier.kernel_size,
    stride=model.decode_head.classifier.stride,
    padding=model.decode_head.classifier.padding
)

model.auxiliary_head.classifier = torch.nn.Conv2d(
    in_channels=model.auxiliary_head.classifier.in_channels,  # Keep the input channels unchanged
    out_channels=4,  # Set the number of output classes to 4
    kernel_size=model.auxiliary_head.classifier.kernel_size,  # Keep other parameters unchanged
    stride=model.auxiliary_head.classifier.stride,
    padding=model.auxiliary_head.classifier.padding
)

# %%
model.eval()  # Set the model to evaluation mode

# Move model to a suitable device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Create a dummy input tensor with the expected shape (batch_size, channels, height, width)
dummy_input = torch.randn(1, 3, 512, 512).to(device)  # Adjust dimensions if necessary

# Print a summary by passing the dummy input
with torch.no_grad():
    output = model(dummy_input)
    print(model)  # This will print the architecture
# Out:
# UperNetForSemanticSegmentation(
#   (backbone): SwinBackbone(
#     (embeddings): SwinEmbeddings(
#       (patch_embeddings): SwinPatchEmbeddings(
#         (projection): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#       )
#       (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): SwinEncoder(
#       (layers): ModuleList(
#         (0): SwinStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (layernorm_before): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=96, out_features=96, bias=True)
#                   (key): Linear(in_features=96, out_features=96, bias=True)
#                   (value): Linear(in_features=96, out_features=96, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=96, out_features=96, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): Identity()
#               (layernorm_after): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=96, out_features=384, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=384, out_features=96, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (layernorm_before): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=96, out_features=96, bias=True)
#                   (key): Linear(in_features=96, out_features=96, bias=True)
#                   (value): Linear(in_features=96, out_features=96, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=96, out_features=96, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.00909090880304575)
#               (layernorm_after): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=96, out_features=384, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=384, out_features=96, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#           (downsample): SwinPatchMerging(
#             (reduction): Linear(in_features=384, out_features=192, bias=False)
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): SwinStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=192, out_features=192, bias=True)
#                   (key): Linear(in_features=192, out_features=192, bias=True)
#                   (value): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.0181818176060915)
#               (layernorm_after): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=192, out_features=768, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=192, out_features=192, bias=True)
#                   (key): Linear(in_features=192, out_features=192, bias=True)
#                   (value): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.027272727340459824)
#               (layernorm_after): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=192, out_features=768, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#           (downsample): SwinPatchMerging(
#             (reduction): Linear(in_features=768, out_features=384, bias=False)
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): SwinStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.036363635212183)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.045454543083906174)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (2): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.054545458406209946)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (3): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.06363636255264282)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (4): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.0727272778749466)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (5): SwinLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=384, out_features=384, bias=True)
#                   (key): Linear(in_features=384, out_features=384, bias=True)
#                   (value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.08181818574666977)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#           (downsample): SwinPatchMerging(
#             (reduction): Linear(in_features=1536, out_features=768, bias=False)
#             (norm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): SwinStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (layernorm_before): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.09090909361839294)
#               (layernorm_after): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (layernorm_before): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (attention): SwinAttention(
#                 (self): SwinSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): SwinSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (drop_path): SwinDropPath(p=0.10000000149011612)
#               (layernorm_after): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (intermediate): SwinIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): SwinOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#         )
#       )
#     )
#     (hidden_states_norms): ModuleDict(
#       (stage1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#       (stage2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (stage3): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (stage4): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decode_head): UperNetHead(
#     (classifier): Conv2d(512, 4, kernel_size=(1, 1), stride=(1, 1))
#     (psp_modules): UperNetPyramidPoolingModule(
#       (0): UperNetPyramidPoolingBlock(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): UperNetConvModule(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#       )
#       (1): UperNetPyramidPoolingBlock(
#         (0): AdaptiveAvgPool2d(output_size=2)
#         (1): UperNetConvModule(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#       )
#       (2): UperNetPyramidPoolingBlock(
#         (0): AdaptiveAvgPool2d(output_size=3)
#         (1): UperNetConvModule(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#       )
#       (3): UperNetPyramidPoolingBlock(
#         (0): AdaptiveAvgPool2d(output_size=6)
#         (1): UperNetConvModule(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#       )
#     )
#     (bottleneck): UperNetConvModule(
#       (conv): Conv2d(2816, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#     (lateral_convs): ModuleList(
#       (0): UperNetConvModule(
#         (conv): Conv2d(96, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#       (1): UperNetConvModule(
#         (conv): Conv2d(192, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#       (2): UperNetConvModule(
#         (conv): Conv2d(384, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#     )
#     (fpn_convs): ModuleList(
#       (0-2): 3 x UperNetConvModule(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#     )
#     (fpn_bottleneck): UperNetConvModule(
#       (conv): Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#   )
#   (auxiliary_head): UperNetFCNHead(
#     (convs): Sequential(
#       (0): UperNetConvModule(
#         (conv): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#     )
#     (classifier): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
# Load the pretrained model state_dict
pretrained_model = UperNetForSemanticSegmentation.from_pretrained("openmmlab/upernet-swin-tiny")
pretrained_state_dict = pretrained_model.state_dict()

# Filter out keys related to decode_head and auxiliary_head
backbone_state_dict = {k: v for k, v in pretrained_state_dict.items() if not (k.startswith("decode_head.") or k.startswith("auxiliary_head."))}

# Load only the filtered state_dict into your modified model
model.load_state_dict(backbone_state_dict, strict=False)
# Out:
# _IncompatibleKeys(missing_keys=['decode_head.classifier.weight', 'decode_head.classifier.bias', 'decode_head.psp_modules.0.1.conv.weight', 'decode_head.psp_modules.0.1.batch_norm.weight', 'decode_head.psp_modules.0.1.batch_norm.bias', 'decode_head.psp_modules.0.1.batch_norm.running_mean', 'decode_head.psp_modules.0.1.batch_norm.running_var', 'decode_head.psp_modules.1.1.conv.weight', 'decode_head.psp_modules.1.1.batch_norm.weight', 'decode_head.psp_modules.1.1.batch_norm.bias', 'decode_head.psp_modules.1.1.batch_norm.running_mean', 'decode_head.psp_modules.1.1.batch_norm.running_var', 'decode_head.psp_modules.2.1.conv.weight', 'decode_head.psp_modules.2.1.batch_norm.weight', 'decode_head.psp_modules.2.1.batch_norm.bias', 'decode_head.psp_modules.2.1.batch_norm.running_mean', 'decode_head.psp_modules.2.1.batch_norm.running_var', 'decode_head.psp_modules.3.1.conv.weight', 'decode_head.psp_modules.3.1.batch_norm.weight', 'decode_head.psp_modules.3.1.batch_norm.bias', 'decode_head.psp_modules.3.1.batch_norm.running_mean', 'decode_head.psp_modules.3.1.batch_norm.running_var', 'decode_head.bottleneck.conv.weight', 'decode_head.bottleneck.batch_norm.weight', 'decode_head.bottleneck.batch_norm.bias', 'decode_head.bottleneck.batch_norm.running_mean', 'decode_head.bottleneck.batch_norm.running_var', 'decode_head.lateral_convs.0.conv.weight', 'decode_head.lateral_convs.0.batch_norm.weight', 'decode_head.lateral_convs.0.batch_norm.bias', 'decode_head.lateral_convs.0.batch_norm.running_mean', 'decode_head.lateral_convs.0.batch_norm.running_var', 'decode_head.lateral_convs.1.conv.weight', 'decode_head.lateral_convs.1.batch_norm.weight', 'decode_head.lateral_convs.1.batch_norm.bias', 'decode_head.lateral_convs.1.batch_norm.running_mean', 'decode_head.lateral_convs.1.batch_norm.running_var', 'decode_head.lateral_convs.2.conv.weight', 'decode_head.lateral_convs.2.batch_norm.weight', 'decode_head.lateral_convs.2.batch_norm.bias', 'decode_head.lateral_convs.2.batch_norm.running_mean', 'decode_head.lateral_convs.2.batch_norm.running_var', 'decode_head.fpn_convs.0.conv.weight', 'decode_head.fpn_convs.0.batch_norm.weight', 'decode_head.fpn_convs.0.batch_norm.bias', 'decode_head.fpn_convs.0.batch_norm.running_mean', 'decode_head.fpn_convs.0.batch_norm.running_var', 'decode_head.fpn_convs.1.conv.weight', 'decode_head.fpn_convs.1.batch_norm.weight', 'decode_head.fpn_convs.1.batch_norm.bias', 'decode_head.fpn_convs.1.batch_norm.running_mean', 'decode_head.fpn_convs.1.batch_norm.running_var', 'decode_head.fpn_convs.2.conv.weight', 'decode_head.fpn_convs.2.batch_norm.weight', 'decode_head.fpn_convs.2.batch_norm.bias', 'decode_head.fpn_convs.2.batch_norm.running_mean', 'decode_head.fpn_convs.2.batch_norm.running_var', 'decode_head.fpn_bottleneck.conv.weight', 'decode_head.fpn_bottleneck.batch_norm.weight', 'decode_head.fpn_bottleneck.batch_norm.bias', 'decode_head.fpn_bottleneck.batch_norm.running_mean', 'decode_head.fpn_bottleneck.batch_norm.running_var', 'auxiliary_head.convs.0.conv.weight', 'auxiliary_head.convs.0.batch_norm.weight', 'auxiliary_head.convs.0.batch_norm.bias', 'auxiliary_head.convs.0.batch_norm.running_mean', 'auxiliary_head.convs.0.batch_norm.running_var', 'auxiliary_head.classifier.weight', 'auxiliary_head.classifier.bias'], unexpected_keys=[])

# %%
import torch

# Zero out all parameters in the decode_head
for name, module in model.decode_head.named_modules():
    if hasattr(module, 'weight') and module.weight is not None:
        with torch.no_grad():  # Ensure gradients are not tracked
            module.weight.zero_()  # Zero out weights
    if hasattr(module, 'bias') and module.bias is not None:
        with torch.no_grad():
            module.bias.zero_()  # Zero out biases

    # Handle BatchNorm running statistics (if applicable)
    if isinstance(module, torch.nn.BatchNorm2d):
        with torch.no_grad():
            module.running_mean.zero_()
            module.running_var.zero_()

# Zero out all parameters in the auxiliary_head (if it exists)
if hasattr(model, 'auxiliary_head'):
    for name, module in model.auxiliary_head.named_modules():
        if hasattr(module, 'weight') and module.weight is not None:
            with torch.no_grad():
                module.weight.zero_()  # Zero out weights
        if hasattr(module, 'bias') and module.bias is not None:
            with torch.no_grad():
                module.bias.zero_()  # Zero out biases

        # Handle BatchNorm running statistics (if applicable)
        if isinstance(module, torch.nn.BatchNorm2d):
            with torch.no_grad():
                module.running_mean.zero_()
                module.running_var.zero_()

# %%
# Print state_dict keys with non-empty and non-zero parameters
for key, param in model.state_dict().items():
    if param.numel() > 0 and torch.sum(param).item() != 0:  # Check for non-empty and non-zero tensors
        print(key)
# Out:
# backbone.embeddings.patch_embeddings.projection.weight
# backbone.embeddings.patch_embeddings.projection.bias
# backbone.embeddings.norm.weight
# backbone.embeddings.norm.bias
# backbone.encoder.layers.0.blocks.0.layernorm_before.weight
# backbone.encoder.layers.0.blocks.0.layernorm_before.bias
# backbone.encoder.layers.0.blocks.0.attention.self.relative_position_bias_table
# backbone.encoder.layers.0.blocks.0.attention.self.relative_position_index
# backbone.encoder.layers.0.blocks.0.attention.self.query.weight
# backbone.encoder.layers.0.blocks.0.attention.self.query.bias
# backbone.encoder.layers.0.blocks.0.attention.self.key.weight
# backbone.encoder.layers.0.blocks.0.attention.self.key.bias
# backbone.encoder.layers.0.blocks.0.attention.self.value.weight
# backbone.encoder.layers.0.blocks.0.attention.self.value.bias
# backbone.encoder.layers.0.blocks.0.attention.output.dense.weight
# backbone.encoder.layers.0.blocks.0.attention.output.dense.bias
# backbone.encoder.layers.0.blocks.0.layernorm_after.weight
# backbone.encoder.layers.0.blocks.0.layernorm_after.bias
# backbone.encoder.layers.0.blocks.0.intermediate.dense.weight
# backbone.encoder.layers.0.blocks.0.intermediate.dense.bias
# backbone.encoder.layers.0.blocks.0.output.dense.weight
# backbone.encoder.layers.0.blocks.0.output.dense.bias
# backbone.encoder.layers.0.blocks.1.layernorm_before.weight
# backbone.encoder.layers.0.blocks.1.layernorm_before.bias
# backbone.encoder.layers.0.blocks.1.attention.self.relative_position_bias_table
# backbone.encoder.layers.0.blocks.1.attention.self.relative_position_index
# backbone.encoder.layers.0.blocks.1.attention.self.query.weight
# backbone.encoder.layers.0.blocks.1.attention.self.query.bias
# backbone.encoder.layers.0.blocks.1.attention.self.key.weight
# backbone.encoder.layers.0.blocks.1.attention.self.key.bias
# backbone.encoder.layers.0.blocks.1.attention.self.value.weight
# backbone.encoder.layers.0.blocks.1.attention.self.value.bias
# backbone.encoder.layers.0.blocks.1.attention.output.dense.weight
# backbone.encoder.layers.0.blocks.1.attention.output.dense.bias
# backbone.encoder.layers.0.blocks.1.layernorm_after.weight
# backbone.encoder.layers.0.blocks.1.layernorm_after.bias
# backbone.encoder.layers.0.blocks.1.intermediate.dense.weight
# backbone.encoder.layers.0.blocks.1.intermediate.dense.bias
# backbone.encoder.layers.0.blocks.1.output.dense.weight
# backbone.encoder.layers.0.blocks.1.output.dense.bias
# backbone.encoder.layers.0.downsample.reduction.weight
# backbone.encoder.layers.0.downsample.norm.weight
# backbone.encoder.layers.0.downsample.norm.bias
# backbone.encoder.layers.1.blocks.0.layernorm_before.weight
# backbone.encoder.layers.1.blocks.0.layernorm_before.bias
# backbone.encoder.layers.1.blocks.0.attention.self.relative_position_bias_table
# backbone.encoder.layers.1.blocks.0.attention.self.relative_position_index
# backbone.encoder.layers.1.blocks.0.attention.self.query.weight
# backbone.encoder.layers.1.blocks.0.attention.self.query.bias
# backbone.encoder.layers.1.blocks.0.attention.self.key.weight
# backbone.encoder.layers.1.blocks.0.attention.self.key.bias
# backbone.encoder.layers.1.blocks.0.attention.self.value.weight
# backbone.encoder.layers.1.blocks.0.attention.self.value.bias
# backbone.encoder.layers.1.blocks.0.attention.output.dense.weight
# backbone.encoder.layers.1.blocks.0.attention.output.dense.bias
# backbone.encoder.layers.1.blocks.0.layernorm_after.weight
# backbone.encoder.layers.1.blocks.0.layernorm_after.bias
# backbone.encoder.layers.1.blocks.0.intermediate.dense.weight
# backbone.encoder.layers.1.blocks.0.intermediate.dense.bias
# backbone.encoder.layers.1.blocks.0.output.dense.weight
# backbone.encoder.layers.1.blocks.0.output.dense.bias
# backbone.encoder.layers.1.blocks.1.layernorm_before.weight
# backbone.encoder.layers.1.blocks.1.layernorm_before.bias
# backbone.encoder.layers.1.blocks.1.attention.self.relative_position_bias_table
# backbone.encoder.layers.1.blocks.1.attention.self.relative_position_index
# backbone.encoder.layers.1.blocks.1.attention.self.query.weight
# backbone.encoder.layers.1.blocks.1.attention.self.query.bias
# backbone.encoder.layers.1.blocks.1.attention.self.key.weight
# backbone.encoder.layers.1.blocks.1.attention.self.key.bias
# backbone.encoder.layers.1.blocks.1.attention.self.value.weight
# backbone.encoder.layers.1.blocks.1.attention.self.value.bias
# backbone.encoder.layers.1.blocks.1.attention.output.dense.weight
# backbone.encoder.layers.1.blocks.1.attention.output.dense.bias
# backbone.encoder.layers.1.blocks.1.layernorm_after.weight
# backbone.encoder.layers.1.blocks.1.layernorm_after.bias
# backbone.encoder.layers.1.blocks.1.intermediate.dense.weight
# backbone.encoder.layers.1.blocks.1.intermediate.dense.bias
# backbone.encoder.layers.1.blocks.1.output.dense.weight
# backbone.encoder.layers.1.blocks.1.output.dense.bias
# backbone.encoder.layers.1.downsample.reduction.weight
# backbone.encoder.layers.1.downsample.norm.weight
# backbone.encoder.layers.1.downsample.norm.bias
# backbone.encoder.layers.2.blocks.0.layernorm_before.weight
# backbone.encoder.layers.2.blocks.0.layernorm_before.bias
# backbone.encoder.layers.2.blocks.0.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.0.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.0.attention.self.query.weight
# backbone.encoder.layers.2.blocks.0.attention.self.query.bias
# backbone.encoder.layers.2.blocks.0.attention.self.key.weight
# backbone.encoder.layers.2.blocks.0.attention.self.key.bias
# backbone.encoder.layers.2.blocks.0.attention.self.value.weight
# backbone.encoder.layers.2.blocks.0.attention.self.value.bias
# backbone.encoder.layers.2.blocks.0.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.0.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.0.layernorm_after.weight
# backbone.encoder.layers.2.blocks.0.layernorm_after.bias
# backbone.encoder.layers.2.blocks.0.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.0.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.0.output.dense.weight
# backbone.encoder.layers.2.blocks.0.output.dense.bias
# backbone.encoder.layers.2.blocks.1.layernorm_before.weight
# backbone.encoder.layers.2.blocks.1.layernorm_before.bias
# backbone.encoder.layers.2.blocks.1.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.1.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.1.attention.self.query.weight
# backbone.encoder.layers.2.blocks.1.attention.self.query.bias
# backbone.encoder.layers.2.blocks.1.attention.self.key.weight
# backbone.encoder.layers.2.blocks.1.attention.self.key.bias
# backbone.encoder.layers.2.blocks.1.attention.self.value.weight
# backbone.encoder.layers.2.blocks.1.attention.self.value.bias
# backbone.encoder.layers.2.blocks.1.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.1.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.1.layernorm_after.weight
# backbone.encoder.layers.2.blocks.1.layernorm_after.bias
# backbone.encoder.layers.2.blocks.1.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.1.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.1.output.dense.weight
# backbone.encoder.layers.2.blocks.1.output.dense.bias
# backbone.encoder.layers.2.blocks.2.layernorm_before.weight
# backbone.encoder.layers.2.blocks.2.layernorm_before.bias
# backbone.encoder.layers.2.blocks.2.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.2.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.2.attention.self.query.weight
# backbone.encoder.layers.2.blocks.2.attention.self.query.bias
# backbone.encoder.layers.2.blocks.2.attention.self.key.weight
# backbone.encoder.layers.2.blocks.2.attention.self.key.bias
# backbone.encoder.layers.2.blocks.2.attention.self.value.weight
# backbone.encoder.layers.2.blocks.2.attention.self.value.bias
# backbone.encoder.layers.2.blocks.2.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.2.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.2.layernorm_after.weight
# backbone.encoder.layers.2.blocks.2.layernorm_after.bias
# backbone.encoder.layers.2.blocks.2.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.2.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.2.output.dense.weight
# backbone.encoder.layers.2.blocks.2.output.dense.bias
# backbone.encoder.layers.2.blocks.3.layernorm_before.weight
# backbone.encoder.layers.2.blocks.3.layernorm_before.bias
# backbone.encoder.layers.2.blocks.3.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.3.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.3.attention.self.query.weight
# backbone.encoder.layers.2.blocks.3.attention.self.query.bias
# backbone.encoder.layers.2.blocks.3.attention.self.key.weight
# backbone.encoder.layers.2.blocks.3.attention.self.key.bias
# backbone.encoder.layers.2.blocks.3.attention.self.value.weight
# backbone.encoder.layers.2.blocks.3.attention.self.value.bias
# backbone.encoder.layers.2.blocks.3.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.3.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.3.layernorm_after.weight
# backbone.encoder.layers.2.blocks.3.layernorm_after.bias
# backbone.encoder.layers.2.blocks.3.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.3.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.3.output.dense.weight
# backbone.encoder.layers.2.blocks.3.output.dense.bias
# backbone.encoder.layers.2.blocks.4.layernorm_before.weight
# backbone.encoder.layers.2.blocks.4.layernorm_before.bias
# backbone.encoder.layers.2.blocks.4.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.4.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.4.attention.self.query.weight
# backbone.encoder.layers.2.blocks.4.attention.self.query.bias
# backbone.encoder.layers.2.blocks.4.attention.self.key.weight
# backbone.encoder.layers.2.blocks.4.attention.self.key.bias
# backbone.encoder.layers.2.blocks.4.attention.self.value.weight
# backbone.encoder.layers.2.blocks.4.attention.self.value.bias
# backbone.encoder.layers.2.blocks.4.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.4.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.4.layernorm_after.weight
# backbone.encoder.layers.2.blocks.4.layernorm_after.bias
# backbone.encoder.layers.2.blocks.4.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.4.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.4.output.dense.weight
# backbone.encoder.layers.2.blocks.4.output.dense.bias
# backbone.encoder.layers.2.blocks.5.layernorm_before.weight
# backbone.encoder.layers.2.blocks.5.layernorm_before.bias
# backbone.encoder.layers.2.blocks.5.attention.self.relative_position_bias_table
# backbone.encoder.layers.2.blocks.5.attention.self.relative_position_index
# backbone.encoder.layers.2.blocks.5.attention.self.query.weight
# backbone.encoder.layers.2.blocks.5.attention.self.query.bias
# backbone.encoder.layers.2.blocks.5.attention.self.key.weight
# backbone.encoder.layers.2.blocks.5.attention.self.key.bias
# backbone.encoder.layers.2.blocks.5.attention.self.value.weight
# backbone.encoder.layers.2.blocks.5.attention.self.value.bias
# backbone.encoder.layers.2.blocks.5.attention.output.dense.weight
# backbone.encoder.layers.2.blocks.5.attention.output.dense.bias
# backbone.encoder.layers.2.blocks.5.layernorm_after.weight
# backbone.encoder.layers.2.blocks.5.layernorm_after.bias
# backbone.encoder.layers.2.blocks.5.intermediate.dense.weight
# backbone.encoder.layers.2.blocks.5.intermediate.dense.bias
# backbone.encoder.layers.2.blocks.5.output.dense.weight
# backbone.encoder.layers.2.blocks.5.output.dense.bias
# backbone.encoder.layers.2.downsample.reduction.weight
# backbone.encoder.layers.2.downsample.norm.weight
# backbone.encoder.layers.2.downsample.norm.bias
# backbone.encoder.layers.3.blocks.0.layernorm_before.weight
# backbone.encoder.layers.3.blocks.0.layernorm_before.bias
# backbone.encoder.layers.3.blocks.0.attention.self.relative_position_bias_table
# backbone.encoder.layers.3.blocks.0.attention.self.relative_position_index
# backbone.encoder.layers.3.blocks.0.attention.self.query.weight
# backbone.encoder.layers.3.blocks.0.attention.self.query.bias
# backbone.encoder.layers.3.blocks.0.attention.self.key.weight
# backbone.encoder.layers.3.blocks.0.attention.self.key.bias
# backbone.encoder.layers.3.blocks.0.attention.self.value.weight
# backbone.encoder.layers.3.blocks.0.attention.self.value.bias
# backbone.encoder.layers.3.blocks.0.attention.output.dense.weight
# backbone.encoder.layers.3.blocks.0.attention.output.dense.bias
# backbone.encoder.layers.3.blocks.0.layernorm_after.weight
# backbone.encoder.layers.3.blocks.0.layernorm_after.bias
# backbone.encoder.layers.3.blocks.0.intermediate.dense.weight
# backbone.encoder.layers.3.blocks.0.intermediate.dense.bias
# backbone.encoder.layers.3.blocks.0.output.dense.weight
# backbone.encoder.layers.3.blocks.0.output.dense.bias
# backbone.encoder.layers.3.blocks.1.layernorm_before.weight
# backbone.encoder.layers.3.blocks.1.layernorm_before.bias
# backbone.encoder.layers.3.blocks.1.attention.self.relative_position_bias_table
# backbone.encoder.layers.3.blocks.1.attention.self.relative_position_index
# backbone.encoder.layers.3.blocks.1.attention.self.query.weight
# backbone.encoder.layers.3.blocks.1.attention.self.query.bias
# backbone.encoder.layers.3.blocks.1.attention.self.key.weight
# backbone.encoder.layers.3.blocks.1.attention.self.key.bias
# backbone.encoder.layers.3.blocks.1.attention.self.value.weight
# backbone.encoder.layers.3.blocks.1.attention.self.value.bias
# backbone.encoder.layers.3.blocks.1.attention.output.dense.weight
# backbone.encoder.layers.3.blocks.1.attention.output.dense.bias
# backbone.encoder.layers.3.blocks.1.layernorm_after.weight
# backbone.encoder.layers.3.blocks.1.layernorm_after.bias
# backbone.encoder.layers.3.blocks.1.intermediate.dense.weight
# backbone.encoder.layers.3.blocks.1.intermediate.dense.bias
# backbone.encoder.layers.3.blocks.1.output.dense.weight
# backbone.encoder.layers.3.blocks.1.output.dense.bias
# backbone.hidden_states_norms.stage1.weight
# backbone.hidden_states_norms.stage1.bias
# backbone.hidden_states_norms.stage2.weight
# backbone.hidden_states_norms.stage2.bias
# backbone.hidden_states_norms.stage3.weight
# backbone.hidden_states_norms.stage3.bias
# backbone.hidden_states_norms.stage4.weight
# backbone.hidden_states_norms.stage4.bias

# %%
# Save only the model's state dictionary
torch.save(model.state_dict(), "upernet-swin-tiny-backbone.pth")
